# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Load image, grayscale, Gaussian blur, Otsu's threshold
image = cv2.imread("/content/drive/MyDrive/CVPROJECT/remote.jpg")
image = cv2.resize(image,(640, 480))
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5,5), 0)
thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

kernel = np.ones((5,5), np.uint8)
img_erosion = cv2.erode(image, kernel, iterations=1)
img_dilation = cv2.dilate(img_erosion, kernel, iterations=1)
# Find bounding box
x,y,w,h = cv2.boundingRect(thresh)
cv2.rectangle(img_dilation, (x, y), (x + w, y + h), (36,255,12), 2)
cv2.putText(img_dilation, "w={},h={}".format(w,h), (x,y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (36,255,12), 2)

cv2_imshow( thresh)
cv2_imshow(img_dilation)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F41DD3E5790>
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F41DD3E5B90>
# -1

# %%
fx=524.61 #in pixels
fy=522.37  #in pixels
w_px=160
h_px=393
sensor_width_mm=4.2
sensor_height_mm=5.6
distance_to_object=150 #150mm

# %%
fx_mm=fx*sensor_width_mm/640
fy_mm=fy*sensor_height_mm/480

# %%
real_width=(distance_to_object*(w_px*sensor_width_mm/640))/fx_mm
real_height=(distance_to_object*(h_px*sensor_height_mm/480))/fy_mm

# %%
real_width
# Out:
# 45.748270143535194

# %%
real_height
# Out:
# 112.85104427895934
